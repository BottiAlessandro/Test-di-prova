# %% [markdown]
# <a href="https://colab.research.google.com/github/6363alle-droid/Test-di-prova/blob/main/FinalTEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x):
    print(x * 2 + 1)

# %%
f(10)
# Out:
# 21

# %%
print("Telli non piangere!")
# Out:
# Telli non piangere!

# %%
print("Arriverai in finale!")
# Out:
# Arriverai in finale!
